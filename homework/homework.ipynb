# %%
import pandas as pd  #  type: ignore

df = pd.read_csv("../files/input/house_data.csv")

features = df[
    [
        "bedrooms",
        "bathrooms",
        "sqft_living",
        "sqft_lot",
        "floors",
        "waterfront",
        "condition",
    ]
]

target = df[["price"]]

# %%
features.bathrooms.value_counts().sort_index().plot(kind="bar")

# %%
"""Build, deploy and access a model using scikit-learn"""

import pickle

import pandas as pd  # type: ignore
from sklearn.linear_model import LinearRegression  # type: ignore

df = pd.read_csv("../files/input/house_data.csv", sep=",")

features = df[
    [
        "bedrooms",
        "bathrooms",
        "sqft_living",
        "sqft_lot",
        "floors",
        "waterfront",
        "condition",
    ]
]

target = df[["price"]]

estimator = LinearRegression()
estimator.fit(features, target)

with open("homework/house_predictor.pkl", "wr") as file:
    pickle.dump(estimator, file)
    
    
    
    
# ----------------
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 27
#      23
#      24 estimator = LinearRegression()
#      25 estimator.fit(features, target)
#      26
# ---> 27 with open("homework/house_predictor.pkl", "wr") as file:
#      28     pickle.dump(estimator, file)
#      29
#      30
#
# ValueError: must have exactly one of create/read/write/append mode

# %%
import pandas as pd  #  type: ignore

df = pd.read_csv("../files/input/house_data.csv")

features = df[
      [
          "bedrooms",
          "bathrooms",
          "sqft_living",
          "sqft_lot",
          "floors",
          "waterfront",
          "condition",
      ]
  ]

target = df[["price"]]


features.bathrooms.value_counts().sort_index().plot(kind="bar")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[20], line 20
#      16
#      17 target = df[["price"]]
#      18
#      19
# ---> 20 features.bathrooms.value_counts().sort_index().plot(kind="bar")
#
# File c:\Users\thom1\Documents\GitHub\analitica\taller-presencial-15-despliegue-de-modelos-de-ml-Thom204\.venv\Lib\site-packages\pandas\plotting\_core.py:1105, in PlotAccessor.__call__(self, *args, **kwargs)
#    1104 def __call__(self, *args, **kwargs):
# -> 1105     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#    1107     x, y, kind, kwargs = self._get_call_args(
#    1108         plot_backend.__name__, self._parent, args, kwargs
#    1109     )
#    1111     kind = self._kind_aliases.get(kind, kind)
#
# File c:\Users\thom1\Documents\GitHub\analitica\taller-presencial-15-despliegue-de-modelos-de-ml-Thom204\.venv\Lib\site-packages\pandas\plotting\_core.py:2253, in _get_plot_backend(backend)
#    2250 if backend_str in _backends:
#    2251     return _backends[backend_str]
# -> 2253 module = _load_backend(backend_str)
#    2254 _backends[backend_str] = module
#    2255 return module
#
# File c:\Users\thom1\Documents\GitHub\analitica\taller-presencial-15-despliegue-de-modelos-de-ml-Thom204\.venv\Lib\site-packages\pandas\plotting\_core.py:2183, in _load_backend(backend)
#    2181         module = importlib.import_module("pandas.plotting._matplotlib")
#    2182     except ImportError:
# -> 2183         raise ImportError(
#    2184             "matplotlib is required for plotting when the "
#    2185             'default backend "matplotlib" is selected.'
#    2186         ) from None
#    2187     return module
#    2189 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
